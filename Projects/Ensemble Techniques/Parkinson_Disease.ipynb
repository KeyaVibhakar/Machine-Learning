# %% [markdown]
# # Case Study: Parkinson's Disease
# ## Technical Aspect: Ensemble Technique

# %% [markdown]
# Parkinson’s Disease (PD) is a degenerative neurological disorder marked by decreased dopamine levels in the brain. It manifests itself through a deterioration of movement, including the presence of tremors and stiffness. There is commonly a marked effect on speech, including dysarthria (difficulty articulating sounds), hypophonia (lowered volume), and monotone (reduced pitch range). Additionally, cognitive impairments and changes in mood can occur, and risk of dementia is increased.
#
#
# Traditional diagnosis of Parkinson’s Disease involves a clinician taking a neurological history of the patient and observing motor skills in various situations. Since there is no definitive laboratory test to diagnose PD, diagnosis is often difficult, particularly in the early stages when motor effects are not yet severe. Monitoring progression of the disease over time requires repeated clinic visits by the patient. An effective screening process, particularly one that doesn’t require a clinic visit, would be beneficial. Since PD patients exhibit characteristic vocal features, voice recordings are a useful and non-invasive tool for diagnosis. If machine learning algorithms could be applied to a voice recording dataset to accurately diagnosis PD, this would be an effective screening step prior to an appointment with a clinician.
#
#
# The data consists of those diagnosed with Parkinson Disease and those who do not.
#
#
# Steps to be followed:
#
#
# 1. Load the dataset
# 2. It is always a good practice to eye-ball raw data to get a feel of the data in terms of number of structure of the file, number of attributes, types of attributes and a general idea of likely challenges in the dataset.
# 3. Using univariate &amp; bivariate analysis to check the individual attributes for their basic statistic such as central values, spread, tails etc. What are your observations?
# 4. Split the dataset into training and test set in the ratio of 70:30 (Training:Test).
# 5. Create the model using “entropy” method of reducing the entropy and fit it to training data.
# 6. Test the model on test data and what is the accuracy achieved. Capture the predicted values and do a crosstab.
# 7. Use regularization parameters of max_depth, min_sample_leaf to recreate the model. What is the impact on the model accuracy? How does regularization help?
# 8. Next implement the decision tree using Random Forest. What is the optimal number of trees that gives the best result?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

from subprocess import call
from IPython.display import Image

# %% [markdown]
# ### 1. Load the dataset

# %%
df = pd.read_csv("parkinsons.data", )

# %%
df.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
#      Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 190      0.07008  0.02764  19.517       0  0.448439  0.657899 -6.538586
# 191      0.04812  0.01810  19.147       0  0.431674  0.683244 -6.195325
# 192      0.03804  0.10715  17.883       0  0.407567  0.655683 -6.787197
# 193      0.03794  0.07223  19.020       0  0.451221  0.643956 -6.744577
# 194      0.03078  0.04398  21.209       0  0.462803  0.664357 -5.724056
#
#       spread2        D2       PPE
# 190  0.121952  2.657476  0.133050
# 191  0.129303  2.784312  0.168895
# 192  0.158453  2.679772  0.131728
# 193  0.207454  2.138608  0.123306
# 194  0.190667  2.555477  0.148569
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
# name                195 non-null object
# MDVP:Fo(Hz)         195 non-null float64
# MDVP:Fhi(Hz)        195 non-null float64
# MDVP:Flo(Hz)        195 non-null float64
# MDVP:Jitter(%)      195 non-null float64
# MDVP:Jitter(Abs)    195 non-null float64
# MDVP:RAP            195 non-null float64
# MDVP:PPQ            195 non-null float64
# Jitter:DDP          195 non-null float64
# MDVP:Shimmer        195 non-null float64
# MDVP:Shimmer(dB)    195 non-null float64
# Shimmer:APQ3        195 non-null float64
# Shimmer:APQ5        195 non-null float64
# MDVP:APQ            195 non-null float64
# Shimmer:DDA         195 non-null float64
# NHR                 195 non-null float64
# HNR                 195 non-null float64
# status              195 non-null int64
# RPDE                195 non-null float64
# DFA                 195 non-null float64
# spread1             195 non-null float64
# spread2             195 non-null float64
# D2                  195 non-null float64
# PPE                 195 non-null float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 36.6+ KB

# %% [markdown]
# ### 2. It is always a good practice to eye-ball raw data to get a feel of the data in terms of number of structure of the file, number of attributes, types of attributes and a general idea of likely challenges in the dataset. (2.5 points)
# ### 3. Using univariate &amp; bivariate analysis to check the individual attributes for their basic statistic such as central values, spread, tails etc. What are your observations? (15 points)

# %%
df.describe().T
# Out:
#                   count        mean        std         min         25%  \
# MDVP:Fo(Hz)       195.0  154.228641  41.390065   88.333000  117.572000
# MDVP:Fhi(Hz)      195.0  197.104918  91.491548  102.145000  134.862500
# MDVP:Flo(Hz)      195.0  116.324631  43.521413   65.476000   84.291000
# MDVP:Jitter(%)    195.0    0.006220   0.004848    0.001680    0.003460
# MDVP:Jitter(Abs)  195.0    0.000044   0.000035    0.000007    0.000020
# MDVP:RAP          195.0    0.003306   0.002968    0.000680    0.001660
# MDVP:PPQ          195.0    0.003446   0.002759    0.000920    0.001860
# Jitter:DDP        195.0    0.009920   0.008903    0.002040    0.004985
# MDVP:Shimmer      195.0    0.029709   0.018857    0.009540    0.016505
# MDVP:Shimmer(dB)  195.0    0.282251   0.194877    0.085000    0.148500
# Shimmer:APQ3      195.0    0.015664   0.010153    0.004550    0.008245
# Shimmer:APQ5      195.0    0.017878   0.012024    0.005700    0.009580
# MDVP:APQ          195.0    0.024081   0.016947    0.007190    0.013080
# Shimmer:DDA       195.0    0.046993   0.030459    0.013640    0.024735
# NHR               195.0    0.024847   0.040418    0.000650    0.005925
# HNR               195.0   21.885974   4.425764    8.441000   19.198000
# status            195.0    0.753846   0.431878    0.000000    1.000000
# RPDE              195.0    0.498536   0.103942    0.256570    0.421306
# DFA               195.0    0.718099   0.055336    0.574282    0.674758
# spread1           195.0   -5.684397   1.090208   -7.964984   -6.450096
# spread2           195.0    0.226510   0.083406    0.006274    0.174351
# D2                195.0    2.381826   0.382799    1.423287    2.099125
# PPE               195.0    0.206552   0.090119    0.044539    0.137451
#
#                          50%         75%         max
# MDVP:Fo(Hz)       148.790000  182.769000  260.105000
# MDVP:Fhi(Hz)      175.829000  224.205500  592.030000
# MDVP:Flo(Hz)      104.315000  140.018500  239.170000
# MDVP:Jitter(%)      0.004940    0.007365    0.033160
# MDVP:Jitter(Abs)    0.000030    0.000060    0.000260
# MDVP:RAP            0.002500    0.003835    0.021440
# MDVP:PPQ            0.002690    0.003955    0.019580
# Jitter:DDP          0.007490    0.011505    0.064330
# MDVP:Shimmer        0.022970    0.037885    0.119080
# MDVP:Shimmer(dB)    0.221000    0.350000    1.302000
# Shimmer:APQ3        0.012790    0.020265    0.056470
# Shimmer:APQ5        0.013470    0.022380    0.079400
# MDVP:APQ            0.018260    0.029400    0.137780
# Shimmer:DDA         0.038360    0.060795    0.169420
# NHR                 0.011660    0.025640    0.314820
# HNR                22.085000   25.075500   33.047000
# status              1.000000    1.000000    1.000000
# RPDE                0.495954    0.587562    0.685151
# DFA                 0.722254    0.761881    0.825288
# spread1            -5.720868   -5.046192   -2.434031
# spread2             0.218885    0.279234    0.450493
# D2                  2.361532    2.636456    3.671155
# PPE                 0.194052    0.252980    0.527367

# %%
df.skew()
# Out:
# MDVP:Fo(Hz)         0.591737
# MDVP:Fhi(Hz)        2.542146
# MDVP:Flo(Hz)        1.217350
# MDVP:Jitter(%)      3.084946
# MDVP:Jitter(Abs)    2.649071
# MDVP:RAP            3.360708
# MDVP:PPQ            3.073892
# Jitter:DDP          3.362058
# MDVP:Shimmer        1.666480
# MDVP:Shimmer(dB)    1.999389
# Shimmer:APQ3        1.580576
# Shimmer:APQ5        1.798697
# MDVP:APQ            2.618047
# Shimmer:DDA         1.580618
# NHR                 4.220709
# HNR                -0.514317
# status             -1.187727
# RPDE               -0.143402
# DFA                -0.033214
# spread1             0.432139
# spread2             0.144430
# D2                  0.430384
# PPE                 0.797491
# dtype: float64

# %%
status_0 = df[df['status'] == 0 ]
status_0.shape
# Out:
# (48, 24)

# %%
status_1 = df[df['status'] == 1 ]
status_1.shape
# Out:
# (147, 24)

# %%
status_0.describe().T
# Out:
#                   count        mean        std         min         25%  \
# MDVP:Fo(Hz)        48.0  181.937771  52.731067  110.739000  120.947500
# MDVP:Fhi(Hz)       48.0  223.636750  96.727067  113.597000  139.413250
# MDVP:Flo(Hz)       48.0  145.207292  58.757070   74.287000   98.243750
# MDVP:Jitter(%)     48.0    0.003866   0.002055    0.001780    0.002655
# MDVP:Jitter(Abs)   48.0    0.000023   0.000015    0.000007    0.000010
# MDVP:RAP           48.0    0.001925   0.001066    0.000920    0.001332
# MDVP:PPQ           48.0    0.002056   0.000943    0.001060    0.001480
# Jitter:DDP         48.0    0.005776   0.003199    0.002760    0.003998
# MDVP:Shimmer       48.0    0.017615   0.005544    0.009540    0.014475
# MDVP:Shimmer(dB)   48.0    0.162958   0.057822    0.085000    0.129000
# Shimmer:APQ3       48.0    0.009504   0.003456    0.004680    0.007350
# Shimmer:APQ5       48.0    0.010509   0.003231    0.006060    0.008193
# MDVP:APQ           48.0    0.013305   0.003825    0.007190    0.011235
# Shimmer:DDA        48.0    0.028511   0.010368    0.014030    0.022060
# NHR                48.0    0.011483   0.019088    0.000650    0.004188
# HNR                48.0   24.678750   3.434540   17.883000   22.993250
# status             48.0    0.000000   0.000000    0.000000    0.000000
# RPDE               48.0    0.442552   0.092199    0.256570    0.372126
# DFA                48.0    0.695716   0.051346    0.626710    0.654291
# spread1            48.0   -6.759264   0.642782   -7.964984   -7.257665
# spread2            48.0    0.160292   0.062982    0.006274    0.120623
# D2                 48.0    2.154491   0.310269    1.423287    1.974217
# PPE                48.0    0.123017   0.044820    0.044539    0.094658
#
#                          50%         75%         max
# MDVP:Fo(Hz)       198.996000  229.077000  260.105000
# MDVP:Fhi(Hz)      231.161500  251.239250  592.030000
# MDVP:Flo(Hz)      113.938500  199.183000  239.170000
# MDVP:Jitter(%)      0.003355    0.004530    0.013600
# MDVP:Jitter(Abs)    0.000025    0.000030    0.000080
# MDVP:RAP            0.001625    0.001907    0.006240
# MDVP:PPQ            0.001775    0.002228    0.005640
# Jitter:DDP          0.004875    0.005725    0.018730
# MDVP:Shimmer        0.016705    0.020210    0.040870
# MDVP:Shimmer(dB)    0.154000    0.189250    0.405000
# Shimmer:APQ3        0.008775    0.011513    0.023360
# Shimmer:APQ5        0.010225    0.011980    0.024980
# MDVP:APQ            0.013015    0.015945    0.027450
# Shimmer:DDA         0.026330    0.034540    0.070080
# NHR                 0.004825    0.009213    0.107150
# HNR                24.997000   26.139250   33.047000
# status              0.000000    0.000000    0.000000
# RPDE                0.435368    0.507748    0.663842
# DFA                 0.682527    0.742284    0.785714
# spread1            -6.826448   -6.350146   -5.198864
# spread2             0.167356    0.193766    0.291954
# D2                  2.129510    2.339487    2.882450
# PPE                 0.115119    0.147761    0.252404

# %%
status_1.describe().T
# Out:
#                   count        mean        std         min         25%  \
# MDVP:Fo(Hz)       147.0  145.180762  32.348050   88.333000  117.572000
# MDVP:Fhi(Hz)      147.0  188.441463  88.339180  102.145000  133.776500
# MDVP:Flo(Hz)      147.0  106.893558  32.274358   65.476000   80.875500
# MDVP:Jitter(%)    147.0    0.006989   0.005240    0.001680    0.004005
# MDVP:Jitter(Abs)  147.0    0.000051   0.000037    0.000010    0.000030
# MDVP:RAP          147.0    0.003757   0.003241    0.000680    0.002030
# MDVP:PPQ          147.0    0.003900   0.002998    0.000920    0.002190
# Jitter:DDP        147.0    0.011273   0.009724    0.002040    0.006085
# MDVP:Shimmer      147.0    0.033658   0.019970    0.010220    0.018295
# MDVP:Shimmer(dB)  147.0    0.321204   0.207798    0.090000    0.168000
# Shimmer:APQ3      147.0    0.017676   0.010797    0.004550    0.009135
# Shimmer:APQ5      147.0    0.020285   0.012847    0.005700    0.010575
# MDVP:APQ          147.0    0.027600   0.018062    0.008110    0.015555
# Shimmer:DDA       147.0    0.053027   0.032391    0.013640    0.027400
# NHR               147.0    0.029211   0.044447    0.002310    0.008445
# HNR               147.0   20.974048   4.339143    8.441000   18.782000
# status            147.0    1.000000   0.000000    1.000000    1.000000
# RPDE              147.0    0.516816   0.101254    0.263654    0.439064
# DFA               147.0    0.725408   0.054786    0.574282    0.685569
# spread1           147.0   -5.333420   0.970792   -7.120925   -6.038300
# spread2           147.0    0.248133   0.077809    0.063412    0.199507
# D2                147.0    2.456058   0.375742    1.765957    2.180933
# PPE               147.0    0.233828   0.084271    0.093193    0.170103
#
#                          50%         75%         max
# MDVP:Fo(Hz)       145.174000  170.071000  223.361000
# MDVP:Fhi(Hz)      163.335000  207.160500  588.518000
# MDVP:Flo(Hz)       99.770000  129.240000  199.020000
# MDVP:Jitter(%)      0.005440    0.007670    0.033160
# MDVP:Jitter(Abs)    0.000040    0.000060    0.000260
# MDVP:RAP            0.002840    0.004100    0.021440
# MDVP:PPQ            0.003140    0.004360    0.019580
# Jitter:DDP          0.008530    0.012300    0.064330
# MDVP:Shimmer        0.028380    0.042525    0.119080
# MDVP:Shimmer(dB)    0.263000    0.394500    1.302000
# Shimmer:APQ3        0.014840    0.022815    0.056470
# Shimmer:APQ5        0.016500    0.024935    0.079400
# MDVP:APQ            0.021570    0.034825    0.137780
# Shimmer:DDA         0.044510    0.068455    0.169420
# NHR                 0.016580    0.027960    0.314820
# HNR                21.414000   24.164500   29.928000
# status              1.000000    1.000000    1.000000
# RPDE                0.530529    0.604573    0.685151
# DFA                 0.726652    0.764868    0.825288
# spread1            -5.440040   -4.664067   -2.434031
# spread2             0.240875    0.303660    0.450493
# D2                  2.439597    2.668479    3.671155
# PPE                 0.222716    0.274397    0.527367

# %%
status_1['MDVP:Flo(Hz)'].mean()
# Out:
# 106.89355782312921

# %%
less = (status_1['MDVP:Flo(Hz)'] < status_1['MDVP:Flo(Hz)'].mean())
status_1[less].shape
# Out:
# (88, 24)

# %%
more = (status_1['MDVP:Flo(Hz)'] > status_1['MDVP:Flo(Hz)'].mean())
status_1[more].shape
# Out:
# (59, 24)

# %% [markdown]
# #### MDVP:Fo(Hz)

# %%
sns.set(style="whitegrid")
sns.boxplot('status','MDVP:Fo(Hz)', data=df)

# %%
plt.figure(figsize=(13,8))
ax=sns.distplot(status_0['MDVP:Fo(Hz)'], hist=False , label='status=0' , color='b')
ax=sns.distplot(status_1['MDVP:Fo(Hz)'], hist=False, label='status=1', color='r')
ax=sns.distplot(df['MDVP:Fo(Hz)'],       hist=False , label='both' ,color='g')
ax.axvline(status_0['MDVP:Fo(Hz)'].mean(),   color='b', linestyle='--', label='Mean:status=0')
ax.axvline(status_0['MDVP:Fo(Hz)'].median(), color='b', linestyle='-',  label='Median:status=0')
ax.axvline(status_1['MDVP:Fo(Hz)'].mean(),   color='r', linestyle='--', label='Mean:status=1')
ax.axvline(status_1['MDVP:Fo(Hz)'].median(), color='r', linestyle='-',  label='Median:status=1')
ax.axvline(df['MDVP:Fo(Hz)'].mean(),   color='g', linestyle='--', label='Mean:both')
ax.axvline(df['MDVP:Fo(Hz)'].median(), color='g', linestyle='-',  label='Median:both')

plt.legend(loc="upper right")

# %%
status_0['MDVP:Fo(Hz)'].skew(), status_1['MDVP:Fo(Hz)'].skew(), df['MDVP:Fo(Hz)'].skew()
# Out:
# (-0.2060804755435577, 0.36684955948316283, 0.5917374636540784)

# %%
status_0['MDVP:Fo(Hz)'].kurtosis(), status_1['MDVP:Fo(Hz)'].kurtosis(), df['MDVP:Fo(Hz)'].kurtosis()
# Out:
# (-1.6481907157014024, -0.7956530227883039, -0.6278981066788805)

# %% [markdown]
# ##### Observations on Average Vocal Fundamental Frequency (Fo) -
#
# * Mean for the sample dataset is greater than median; hence, the distribution is right tailed, with positively skewed.
# * We can observe that distribution for people with PD; is also right-tailed, though, relatively less skewed.
# * However, distribution for people without PD is negatively skewed.
#
# * We also observe that there is a lesser variability for people with PD than that of people without PD.

# %% [markdown]
# #### MDVP:Fhi(Hz)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot('status','MDVP:Fhi(Hz)', data=df, fliersize=6 )

# %% [markdown]
# ###### Analysis of outliers - using IQR and Z-score

# %%
# Outliers according to IQR Method
Q1 = status_1['MDVP:Fhi(Hz)'].quantile(0.25)
Q3 = status_1['MDVP:Fhi(Hz)'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
upper = (Q3 + 1.5 * IQR)
lower =  (Q1 - 1.5 * IQR)
status_1[(status_1['MDVP:Fhi(Hz)'] < lower) | (status_1['MDVP:Fhi(Hz)'] > upper)]
# Out:
# 73.38400000000001
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 16   phon_R01_S04_5      144.188       349.259        82.764         0.00544
# 73   phon_R01_S19_2      112.014       588.518       107.024         0.00533
# 102  phon_R01_S24_6      139.224       586.567        66.157         0.03011
# 115  phon_R01_S27_1      151.872       492.892        69.085         0.00856
# 116  phon_R01_S27_2      158.219       442.557        71.948         0.00476
# 117  phon_R01_S27_3      170.756       450.247        79.032         0.00555
# 118  phon_R01_S27_4      178.285       442.824        82.063         0.00462
# 120  phon_R01_S27_6      128.940       479.697        88.251         0.00581
# 149  phon_R01_S35_4      202.632       565.740       177.258         0.01627
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 16            0.00004   0.00211   0.00292     0.00632       0.02047  ...
# 73            0.00005   0.00268   0.00329     0.00805       0.02448  ...
# 102           0.00022   0.01854   0.01628     0.05563       0.09419  ...
# 115           0.00006   0.00404   0.00385     0.01211       0.01843  ...
# 116           0.00003   0.00214   0.00207     0.00642       0.01458  ...
# 117           0.00003   0.00244   0.00261     0.00731       0.01725  ...
# 118           0.00003   0.00157   0.00194     0.00472       0.01279  ...
# 120           0.00005   0.00241   0.00314     0.00723       0.02008  ...
# 149           0.00008   0.00919   0.00963     0.02756       0.07170  ...
#
#      Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 16       0.02908  0.01859  22.333       1  0.567380  0.644692 -5.440040
# 73       0.04120  0.00623  24.178       1  0.509127  0.789532 -5.389129
# 102      0.16654  0.25930  10.489       1  0.596362  0.641418 -3.269487
# 115      0.02389  0.06051  23.693       1  0.407701  0.662668 -4.673241
# 116      0.01818  0.01554  26.356       1  0.450798  0.653823 -6.051233
# 117      0.02270  0.01802  25.690       1  0.486738  0.676023 -4.597834
# 118      0.01851  0.00856  25.020       1  0.470422  0.655239 -4.913137
# 120      0.02548  0.02350  24.743       1  0.487756  0.684130 -6.186128
# 149      0.10546  0.07889  14.989       1  0.427627  0.775708 -4.892495
#
#       spread2        D2       PPE
# 16   0.239764  2.264501  0.218164
# 73   0.306636  1.928708  0.225461
# 102  0.270641  2.690917  0.444774
# 115  0.261549  2.702355  0.274407
# 116  0.273280  2.640798  0.170106
# 117  0.372114  2.975889  0.282780
# 118  0.393056  2.816781  0.251972
# 120  0.279933  2.686240  0.152428
# 149  0.262281  2.910213  0.270173
#
# [9 rows x 24 columns]

# %%
# Outliers according to Z-Score Method
z = np.abs(stats.zscore(status_1['MDVP:Fhi(Hz)']))
status_1[z > 3]
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 73   phon_R01_S19_2      112.014       588.518       107.024         0.00533
# 102  phon_R01_S24_6      139.224       586.567        66.157         0.03011
# 115  phon_R01_S27_1      151.872       492.892        69.085         0.00856
# 120  phon_R01_S27_6      128.940       479.697        88.251         0.00581
# 149  phon_R01_S35_4      202.632       565.740       177.258         0.01627
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 73            0.00005   0.00268   0.00329     0.00805       0.02448  ...
# 102           0.00022   0.01854   0.01628     0.05563       0.09419  ...
# 115           0.00006   0.00404   0.00385     0.01211       0.01843  ...
# 120           0.00005   0.00241   0.00314     0.00723       0.02008  ...
# 149           0.00008   0.00919   0.00963     0.02756       0.07170  ...
#
#      Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 73       0.04120  0.00623  24.178       1  0.509127  0.789532 -5.389129
# 102      0.16654  0.25930  10.489       1  0.596362  0.641418 -3.269487
# 115      0.02389  0.06051  23.693       1  0.407701  0.662668 -4.673241
# 120      0.02548  0.02350  24.743       1  0.487756  0.684130 -6.186128
# 149      0.10546  0.07889  14.989       1  0.427627  0.775708 -4.892495
#
#       spread2        D2       PPE
# 73   0.306636  1.928708  0.225461
# 102  0.270641  2.690917  0.444774
# 115  0.261549  2.702355  0.274407
# 120  0.279933  2.686240  0.152428
# 149  0.262281  2.910213  0.270173
#
# [5 rows x 24 columns]

# %%
plt.figure(figsize=(13,8))
ax=sns.distplot(status_0['MDVP:Fhi(Hz)'], hist=False , label='status=0' , color='b')
ax=sns.distplot(status_1['MDVP:Fhi(Hz)'], hist=False,  label='status=1',  color='r')
ax=sns.distplot( df['MDVP:Fhi(Hz)'],      hist=False , label='both',      color='g')
ax.axvline(status_0['MDVP:Fhi(Hz)'].mean(),   color='b', linestyle='--',  label='Mean:status=0')
ax.axvline(status_0['MDVP:Fhi(Hz)'].median(), color='b', linestyle='-',   label='Median:status=0')
ax.axvline(status_1['MDVP:Fhi(Hz)'].mean(),   color='r', linestyle='--',  label='Mean:status=1')
ax.axvline(status_1['MDVP:Fhi(Hz)'].median(), color='r', linestyle='-',   label='Median:status=1')
ax.axvline(df['MDVP:Fhi(Hz)'].mean(),         color='g', linestyle='--',  label='Mean:both')
ax.axvline(df['MDVP:Fhi(Hz)'].median(),       color='g', linestyle='-',   label='Median:both')

plt.legend(loc="upper right")

# %%
status_0['MDVP:Fhi(Hz)'].skew(), status_1['MDVP:Fhi(Hz)'].skew(), df['MDVP:Fhi(Hz)'].skew()
# Out:
# (2.1913567763615234, 2.8032726878545318, 2.542145997588398)

# %%
status_0['MDVP:Fhi(Hz)'].kurtosis(), status_1['MDVP:Fhi(Hz)'].kurtosis(), df['MDVP:Fhi(Hz)'].kurtosis()
# Out:
# (6.983751803630555, 8.839929259869601, 7.627241211631889)

# %% [markdown]
# ##### Observations on Maximum Vocal Fundamental Frequency (Fhi) -
#
# * mean for the dataset is greater than median; hence, the distribution is right tailed or +ve skewed.
# * We can observe that distribution for people with PD; is also right tailed or +ve skewed. Infact, more +ve skewed than complete dataset.
# * Distribution for people without PD is also +ve skewed.
#
# * Kurtosis for people with PD is higher than People without PD
#
# * We also observe that there is a lesser variability for people with PD than that of people without PD; however, there are larger number of outliers for people with PD compared to people without PD.

# %% [markdown]
# #### MDVP:Flo(Hz)

# %%
sns.boxplot('status','MDVP:Flo(Hz)', data=df)

# %%
status_0['MDVP:Flo(Hz)'].skew(), status_1['MDVP:Flo(Hz)'].skew(), df['MDVP:Flo(Hz)'].skew()
# Out:
# (0.45440071659018355, 0.8936644548189732, 1.217350448627808)

# %%
status_0['MDVP:Flo(Hz)'].kurtosis(), status_1['MDVP:Flo(Hz)'].kurtosis(), df['MDVP:Flo(Hz)'].kurtosis()
# Out:
# (-1.5684019767347284, -0.11332150570209354, 0.6546145211395396)

# %%
plt.figure(figsize=(13,8))
ax = sns.distplot(status_0['MDVP:Flo(Hz)'], hist=False , label='status=0', color='b')
ax = sns.distplot(status_1['MDVP:Flo(Hz)'], hist=False, label='status=1',  color='r')
ax = sns.distplot(df['MDVP:Flo(Hz)'],       hist=False , label='both',     color='g')
ax.axvline(status_0['MDVP:Flo(Hz)'].mean(),   color='b', linestyle='--', label='Mean:status=0')
ax.axvline(status_0['MDVP:Flo(Hz)'].median(), color='b', linestyle='-',  label='Median:status=0')
ax.axvline(status_1['MDVP:Flo(Hz)'].mean(),   color='r', linestyle='--', label='Mean:status=1')
ax.axvline(status_1['MDVP:Flo(Hz)'].median(), color='r', linestyle='-',  label='Median:status=1')
ax.axvline(df['MDVP:Flo(Hz)'].mean(),         color='g', linestyle='--',  label='Mean:both')
ax.axvline(df['MDVP:Flo(Hz)'].median(),       color='g', linestyle='-',   label='Median:both')

plt.legend(loc="upper right")

# %% [markdown]
# #### MDVP:Jitter(%)

# %% [markdown]
# Domain notes:
#
# * Jitter and shimmer are the two common perturbation measures in acoustic analysis.
# * Jitter is a measure of frequency instability, while shimmer is a measure of amplitude instability.
# * __A normal voice has a small amount of instability during sustained vowel production.__

# %%
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharey=False, figsize=(14,6))
sns.boxplot('MDVP:Jitter(%)', data=status_0, ax=ax0, orient="v", color='b')
sns.boxplot('MDVP:Jitter(%)', data=status_1, ax=ax1, orient="v", color='r')
sns.boxplot('MDVP:Jitter(%)', data=df,       ax=ax2, orient="v", color='g')
ax0.set_title('status=0')
ax1.set_title('status=1')
ax2.set_title('status=both')
plt.show()

# %%
plt.figure(figsize=(13,8))
ax=sns.distplot(status_0['MDVP:Jitter(%)'], hist=False, color='b', label='status=0')
ax=sns.distplot(status_1['MDVP:Jitter(%)'], hist=False, color='r', label='status=1')
ax=sns.distplot(df['MDVP:Jitter(%)'],       hist=False, color='g', label='both')
ax.axvline(status_0['MDVP:Jitter(%)'].mean(),   color='b', linestyle='--', label='Mean:status=0')
ax.axvline(status_0['MDVP:Jitter(%)'].median(), color='b', linestyle='-',  label='Median:status=0')
ax.axvline(status_1['MDVP:Jitter(%)'].mean(),   color='r', linestyle='--', label='Mean:status=1')
ax.axvline(status_1['MDVP:Jitter(%)'].median(), color='r', linestyle='-',  label='Median:status=1')
plt.legend(loc='upper right')
plt.show()

# %%
status_0['MDVP:Jitter(%)'].skew(), status_1['MDVP:Jitter(%)'].skew(), df['MDVP:Jitter(%)'].skew()
# Out:
# (2.59519606641597, 2.8574858039979762, 3.0849462014441817)

# %%
status_0['MDVP:Jitter(%)'].kurtosis(), status_1['MDVP:Jitter(%)'].kurtosis(), df['MDVP:Jitter(%)'].kurtosis()
# Out:
# (9.942782358628424, 9.834618549446867, 12.030939276179508)

# %% [markdown]
# ##### Observations on MDVP jitter in percentage -
# * People with PD have high Jitter Percentage than people without PD
# * People with PD have many outliers, indicating that Jitter Percentage can be excessively high among many PD patients.

# %% [markdown]
# #### MDVP:Jitter(Abs)

# %%
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharey=False, figsize=(14,6))
sns.boxplot('MDVP:Jitter(Abs)', data=status_0, ax=ax0, orient="v", color='b')
sns.boxplot('MDVP:Jitter(Abs)', data=status_1, ax=ax1, orient="v", color='r')
sns.boxplot('MDVP:Jitter(Abs)', data=df,       ax=ax2, orient="v", color='g')
ax0.set_title('status=0')
ax1.set_title('status=1')
ax2.set_title('status=both')
plt.show()

# %%
plt.figure(figsize=(13,8))
ax=sns.distplot(status_0['MDVP:Jitter(Abs)'], hist=False, color='b', label='status=0')
ax=sns.distplot(status_1['MDVP:Jitter(Abs)'], hist=False, color='r', label='status=1')
ax=sns.distplot(df['MDVP:Jitter(Abs)'],       hist=False, color='g', label='both')
ax.axvline(status_0['MDVP:Jitter(Abs)'].mean(),   color='b', linestyle='--', label='Mean:status=0')
ax.axvline(status_0['MDVP:Jitter(Abs)'].median(), color='b', linestyle='-',  label='Median:status=0')
ax.axvline(status_1['MDVP:Jitter(Abs)'].mean(),   color='r', linestyle='--', label='Mean:status=1')
ax.axvline(status_1['MDVP:Jitter(Abs)'].median(), color='r', linestyle='-',  label='Median:status=1')
plt.legend(loc='upper right')
plt.show()

# %%
status_0['MDVP:Jitter(Abs)'].skew(), status_1['MDVP:Jitter(Abs)'].skew(), df['MDVP:Jitter(Abs)'].skew()
# Out:
# (1.2035082315190633, 2.554054663844502, 2.6490714165257274)

# %%
status_0['MDVP:Jitter(Abs)'].kurtosis(), status_1['MDVP:Jitter(Abs)'].kurtosis(), df['MDVP:Jitter(Abs)'].kurtosis()
# Out:
# (2.6354731415288413, 9.657518966591816, 10.869042517763667)

# %% [markdown]
# ##### Observations on MDVP jitter (Abs) -
# * People with PD have higher Absolute Jitter than people without PD
# * People with PD have many outliers, indicating that Absolute Jitter can be excessively high among some PD patients.
# * High Kurtosis (9.65) in People with PD indicate heavy tails.

# %% [markdown]
# #### MDVP:Shimmer

# %%
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharey=False, figsize=(14,6))
sns.boxplot('MDVP:Shimmer', data=status_0, ax=ax0, orient="v", color='b')
sns.boxplot('MDVP:Shimmer', data=status_1, ax=ax1, orient="v", color='r')
sns.boxplot('MDVP:Shimmer', data=df,       ax=ax2, orient="v", color='g')
ax0.set_title('status=0')
ax1.set_title('status=1')
ax2.set_title('status=both')
plt.show()

# %%
plt.figure(figsize=(13,8))
ax=sns.distplot(status_0['MDVP:Shimmer'], hist=False, color='b', label='status=0')
ax=sns.distplot(status_1['MDVP:Shimmer'], hist=False, color='r', label='status=1')
ax=sns.distplot(df['MDVP:Shimmer'],       hist=False, color='g', label='both')
ax.axvline(status_0['MDVP:Shimmer'].mean(),   color='b', linestyle='--', label='Mean:status=0')
ax.axvline(status_0['MDVP:Shimmer'].median(), color='b', linestyle='-',  label='Median:status=0')
ax.axvline(status_1['MDVP:Shimmer'].mean(),   color='r', linestyle='--', label='Mean:status=1')
ax.axvline(status_1['MDVP:Shimmer'].median(), color='r', linestyle='-',  label='Median:status=1')
plt.legend(loc='upper right')
plt.show()

# %%
status_0['MDVP:Shimmer'].skew(), status_1['MDVP:Shimmer'].skew(), df['MDVP:Shimmer'].skew()
# Out:
# (1.632775056772775, 1.3701457156827381, 1.6664804101559663)

# %%
status_0['MDVP:Shimmer'].kurtosis(), status_1['MDVP:Shimmer'].kurtosis(), df['MDVP:Shimmer'].kurtosis()
# Out:
# (5.353303951189468, 2.194032743932538, 3.2383081111007535)

# %% [markdown]
# #### RPDE

# %%
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharey=False, figsize=(14,6))
sns.boxplot('RPDE', data=status_0, ax=ax0, orient="v", color='b')
sns.boxplot('RPDE', data=status_1, ax=ax1, orient="v", color='r')
sns.boxplot('RPDE', data=df,       ax=ax2, orient="v", color='g')
ax0.set_title('status=0')
ax1.set_title('status=1')
ax2.set_title('status=both')
plt.show()

# %%
plt.figure(figsize=(13,8))
ax=sns.distplot( status_0['RPDE'], hist=False, color='b', label='status=0')
ax=sns.distplot( status_1['RPDE'], hist=False, color='r', label='status=1')
ax=sns.distplot( df['RPDE'],       hist=False, color='g', label='both')
ax.axvline(status_0['RPDE'].mean(), color='b', linestyle='--', label='Mean:status=0')
ax.axvline(status_0['RPDE'].median(), color='b', linestyle='-', label='Median:status=0')
ax.axvline(status_1['RPDE'].mean(), color='r', linestyle='--', label='Mean:status=1')
ax.axvline(status_1['RPDE'].median(), color='r', linestyle='-', label='Median:status=1')
plt.legend(loc='upper right')
plt.show()

# %%
status_0['RPDE'].skew(), status_1['RPDE'].skew(), df['RPDE'].skew()
# Out:
# (0.3114385965198886, -0.33028862350073196, -0.14340241379821705)

# %%
status_0['RPDE'].kurtosis(), status_1['RPDE'].kurtosis(), df['RPDE'].kurtosis()
# Out:
# (-0.267557277574499, -0.8249206102733107, -0.9217809777573227)

# %% [markdown]
# ##### Observations on RPDE (Recurrence period density entropy measure) -
# * People with PD have high RPDE than people without PD

# %% [markdown]
# #### DFA

# %%
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(14,6))
sns.boxplot('DFA', data=status_0, ax=ax0, orient="v", color='b')
sns.boxplot('DFA', data=status_1, ax=ax1, orient="v", color='r')
sns.boxplot('DFA', data=df,       ax=ax2, orient="v", color='g')
ax0.set_title('status=0')
ax1.set_title('status=1')
ax2.set_title('status=both')
plt.show()

# %%
plt.figure(figsize=(13,8))
ax=sns.distplot( status_0['DFA'], hist=False, color='b', label='status=0')
ax=sns.distplot( status_1['DFA'], hist=False, color='r', label='status=1')
ax=sns.distplot( df['DFA'],       hist=False, color='g', label='both')
ax.axvline(status_0['DFA'].mean(), color='b', linestyle='--',   label='Mean:status=0')
ax.axvline(status_0['DFA'].median(), color='b', linestyle='-',  label='Median:status=0')
ax.axvline(status_1['DFA'].mean(),   color='r', linestyle='--', label='Mean:status=1')
ax.axvline(status_1['DFA'].median(), color='r', linestyle='-',  label='Median:status=1')
ax.axvline(df['DFA'].mean(),         color='g', linestyle='--', label='Mean:both')
ax.axvline(df['DFA'].median(),       color='g', linestyle='-',  label='Median:both')
plt.legend(loc='upper right')
plt.show()

# %%
status_0['DFA'].skew(), status_1['DFA'].skew(), df['DFA'].skew()
# Out:
# (0.2786650151529157, -0.15146028089468055, -0.03321366071383484)

# %%
status_0['DFA'].kurtosis(), status_1['DFA'].kurtosis(), df['DFA'].kurtosis()
# Out:
# (-1.4841778159888626, -0.36831052789471963, -0.6861518492559342)

# %% [markdown]
# #### Correlation among different attributes (Bivariate Analysis)

# %%
 df.corr()[(df.corr() > 0.4) | (df.corr() < -0.4)]
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546             NaN
# MDVP:Fhi(Hz)         0.400985      1.000000           NaN             NaN
# MDVP:Flo(Hz)         0.596546           NaN      1.000000             NaN
# MDVP:Jitter(%)            NaN           NaN           NaN        1.000000
# MDVP:Jitter(Abs)          NaN           NaN           NaN        0.935714
# MDVP:RAP                  NaN           NaN           NaN        0.990276
# MDVP:PPQ                  NaN           NaN           NaN        0.974256
# Jitter:DDP                NaN           NaN           NaN        0.990276
# MDVP:Shimmer              NaN           NaN           NaN        0.769063
# MDVP:Shimmer(dB)          NaN           NaN           NaN        0.804289
# Shimmer:APQ3              NaN           NaN           NaN        0.746625
# Shimmer:APQ5              NaN           NaN           NaN        0.725561
# MDVP:APQ                  NaN           NaN           NaN        0.758255
# Shimmer:DDA               NaN           NaN           NaN        0.746635
# NHR                       NaN           NaN           NaN        0.906959
# HNR                       NaN           NaN           NaN       -0.728165
# status                    NaN           NaN           NaN             NaN
# RPDE                      NaN           NaN     -0.400143             NaN
# DFA                 -0.446013           NaN           NaN             NaN
# spread1             -0.413738           NaN           NaN        0.693577
# spread2                   NaN           NaN           NaN             NaN
# D2                        NaN           NaN           NaN        0.433434
# PPE                       NaN           NaN           NaN        0.721543
#
#                   MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  \
# MDVP:Fo(Hz)                    NaN       NaN       NaN         NaN
# MDVP:Fhi(Hz)                   NaN       NaN       NaN         NaN
# MDVP:Flo(Hz)                   NaN       NaN       NaN         NaN
# MDVP:Jitter(%)            0.935714  0.990276  0.974256    0.990276
# MDVP:Jitter(Abs)          1.000000  0.922911  0.897778    0.922913
# MDVP:RAP                  0.922911  1.000000  0.957317    1.000000
# MDVP:PPQ                  0.897778  0.957317  1.000000    0.957319
# Jitter:DDP                0.922913  1.000000  0.957319    1.000000
# MDVP:Shimmer              0.703322  0.759581  0.797826    0.759555
# MDVP:Shimmer(dB)          0.716601  0.790652  0.839239    0.790621
# Shimmer:APQ3              0.697153  0.744912  0.763580    0.744894
# Shimmer:APQ5              0.648961  0.709927  0.786780    0.709907
# MDVP:APQ                  0.648793  0.737455  0.804139    0.737439
# Shimmer:DDA               0.697170  0.744919  0.763592    0.744901
# NHR                       0.834972  0.919521  0.844604    0.919548
# HNR                      -0.656810 -0.721543 -0.731510   -0.721494
# status                         NaN       NaN       NaN         NaN
# RPDE                      0.441839       NaN       NaN         NaN
# DFA                            NaN       NaN       NaN         NaN
# spread1                   0.735779  0.648328  0.716489    0.648328
# spread2                        NaN       NaN  0.407605         NaN
# D2                             NaN  0.426605  0.412524    0.426556
# PPE                       0.748162  0.670999  0.769647    0.671005
#
#                   MDVP:Shimmer  MDVP:Shimmer(dB)  ...  Shimmer:DDA       NHR  \
# MDVP:Fo(Hz)                NaN               NaN  ...          NaN       NaN
# MDVP:Fhi(Hz)               NaN               NaN  ...          NaN       NaN
# MDVP:Flo(Hz)               NaN               NaN  ...          NaN       NaN
# MDVP:Jitter(%)        0.769063          0.804289  ...     0.746635  0.906959
# MDVP:Jitter(Abs)      0.703322          0.716601  ...     0.697170  0.834972
# MDVP:RAP              0.759581          0.790652  ...     0.744919  0.919521
# MDVP:PPQ              0.797826          0.839239  ...     0.763592  0.844604
# Jitter:DDP            0.759555          0.790621  ...     0.744901  0.919548
# MDVP:Shimmer          1.000000          0.987258  ...     0.987626  0.722194
# MDVP:Shimmer(dB)      0.987258          1.000000  ...     0.963202  0.744477
# Shimmer:APQ3          0.987625          0.963198  ...     1.000000  0.716207
# Shimmer:APQ5          0.982835          0.973751  ...     0.960072  0.658080
# MDVP:APQ              0.950083          0.960977  ...     0.896647  0.694019
# Shimmer:DDA           0.987626          0.963202  ...     1.000000  0.716215
# NHR                   0.722194          0.744477  ...     0.716215  1.000000
# HNR                  -0.835271         -0.827805  ...    -0.827130 -0.714072
# status                     NaN               NaN  ...          NaN       NaN
# RPDE                  0.447424          0.410684  ...     0.435237       NaN
# DFA                        NaN               NaN  ...          NaN       NaN
# spread1               0.654734          0.652547  ...     0.610971  0.540865
# spread2               0.452025          0.454314  ...     0.402223       NaN
# D2                    0.507088          0.512233  ...     0.467261  0.470949
# PPE                   0.693771          0.695058  ...     0.645389  0.552591
#
#                        HNR    status      RPDE       DFA   spread1   spread2  \
# MDVP:Fo(Hz)            NaN       NaN       NaN -0.446013 -0.413738       NaN
# MDVP:Fhi(Hz)           NaN       NaN       NaN       NaN       NaN       NaN
# MDVP:Flo(Hz)           NaN       NaN -0.400143       NaN       NaN       NaN
# MDVP:Jitter(%)   -0.728165       NaN       NaN       NaN  0.693577       NaN
# MDVP:Jitter(Abs) -0.656810       NaN  0.441839       NaN  0.735779       NaN
# MDVP:RAP         -0.721543       NaN       NaN       NaN  0.648328       NaN
# MDVP:PPQ         -0.731510       NaN       NaN       NaN  0.716489  0.407605
# Jitter:DDP       -0.721494       NaN       NaN       NaN  0.648328       NaN
# MDVP:Shimmer     -0.835271       NaN  0.447424       NaN  0.654734  0.452025
# MDVP:Shimmer(dB) -0.827805       NaN  0.410684       NaN  0.652547  0.454314
# Shimmer:APQ3     -0.827123       NaN  0.435242       NaN  0.610967  0.402243
# Shimmer:APQ5     -0.813753       NaN       NaN       NaN  0.646809  0.457195
# MDVP:APQ         -0.800407       NaN  0.451379       NaN  0.673158  0.502188
# Shimmer:DDA      -0.827130       NaN  0.435237       NaN  0.610971  0.402223
# NHR              -0.714072       NaN       NaN       NaN  0.540865       NaN
# HNR               1.000000       NaN -0.598736       NaN -0.673210 -0.431564
# status                 NaN  1.000000       NaN       NaN  0.564838  0.454842
# RPDE             -0.598736       NaN  1.000000       NaN  0.591117  0.479905
# DFA                    NaN       NaN       NaN  1.000000       NaN       NaN
# spread1          -0.673210  0.564838  0.591117       NaN  1.000000  0.652358
# spread2          -0.431564  0.454842  0.479905       NaN  0.652358  1.000000
# D2               -0.601401       NaN       NaN       NaN  0.495123  0.523532
# PPE              -0.692876  0.531039  0.545886       NaN  0.962435  0.644711
#
#                         D2       PPE
# MDVP:Fo(Hz)            NaN       NaN
# MDVP:Fhi(Hz)           NaN       NaN
# MDVP:Flo(Hz)           NaN       NaN
# MDVP:Jitter(%)    0.433434  0.721543
# MDVP:Jitter(Abs)       NaN  0.748162
# MDVP:RAP          0.426605  0.670999
# MDVP:PPQ          0.412524  0.769647
# Jitter:DDP        0.426556  0.671005
# MDVP:Shimmer      0.507088  0.693771
# MDVP:Shimmer(dB)  0.512233  0.695058
# Shimmer:APQ3      0.467265  0.645377
# Shimmer:APQ5      0.502174  0.702456
# MDVP:APQ          0.536869  0.721694
# Shimmer:DDA       0.467261  0.645389
# NHR               0.470949  0.552591
# HNR              -0.601401 -0.692876
# status                 NaN  0.531039
# RPDE                   NaN  0.545886
# DFA                    NaN       NaN
# spread1           0.495123  0.962435
# spread2           0.523532  0.644711
# D2                1.000000  0.480585
# PPE               0.480585  1.000000
#
# [23 rows x 23 columns]

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# #### Observations from correlation heatmap:
# 1) All the given measures of 'Jitter'( MDMDVP:Jitter(%), MDVP:Jitter(Abs), MDVP:RAP, MDVP:PPQ, Jitter:DDP) are highly correlated. Hence, we can represent presence of Jitter, during model building, using just one of them. Since, __MDVP:Jitter(Abs)__ has highest correlation with our target variable (status); we can use only __MDVP:Jitter(Abs)__ for model building.
#
# 2) All the given measures of 'Shimmer'( MDVP:Shimmer, MDVP:Shimmer(dB), Shimmer:APQ3, Shimmer:APQ5, MDVP:APQ, Shimmer:DDA) are highly correlated. Hence, we can represent presence of Shimmer, during model building, using just one of them. Since, __MDVP:Shimmer__ has highest correlation with our target variable (status); we can use only __MDVP:Shimmer__ for model building.
#
# 3) Since NHR and HNR are highly correlated with Jitter and Shimmer, and so represented by Shimmer and Jitter, we can skip them for model building.

# %% [markdown]
# * Features that can be used for prediction (Although, I have built the model using all the features rather than just the list below. This is because Decission Tree doesn't care about features having high correlation. It just goes for maximum information gain at every split)
#
#     1) MDVP:Fo(Hz)
#
#     2) MDVP:Fhi(Hz)
#
#     3) MDVP:Flo(Hz)
#
#     4) MDVP:Jitter(Abs)
#
#     5) MDVP:Shimmer
#
#     6) RPDE
#
#     7) DFA
#
#     8) spread1
#
#     9) spread2
#
#     10) D2
#
#     11) PPE

# %% [markdown]
# #### name

# %%
df['just_name'] = df['name'].apply(lambda a : a[:-2])
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#        NHR     HNR  status      RPDE       DFA   spread1   spread2        D2  \
# 0  0.02211  21.033       1  0.414783  0.815285 -4.813031  0.266482  2.301442
# 1  0.01929  19.085       1  0.458359  0.819521 -4.075192  0.335590  2.486855
# 2  0.01309  20.651       1  0.429895  0.825288 -4.443179  0.311173  2.342259
# 3  0.01353  20.644       1  0.434969  0.819235 -4.117501  0.334147  2.405554
# 4  0.01767  19.649       1  0.417356  0.823484 -3.747787  0.234513  2.332180
#
#         PPE     just_name
# 0  0.284654  phon_R01_S01
# 1  0.368674  phon_R01_S01
# 2  0.332634  phon_R01_S01
# 3  0.368975  phon_R01_S01
# 4  0.410335  phon_R01_S01
#
# [5 rows x 25 columns]

# %%
pd.crosstab(index=df['just_name'], columns=df['status'])
# Out:
# status        0  1
# just_name
# phon_R01_S01  0  6
# phon_R01_S02  0  6
# phon_R01_S04  0  6
# phon_R01_S05  0  6
# phon_R01_S06  0  6
# phon_R01_S07  6  0
# phon_R01_S08  0  6
# phon_R01_S10  6  0
# phon_R01_S13  6  0
# phon_R01_S16  0  6
# phon_R01_S17  6  0
# phon_R01_S18  0  6
# phon_R01_S19  0  6
# phon_R01_S20  0  6
# phon_R01_S21  0  7
# phon_R01_S22  0  6
# phon_R01_S24  0  6
# phon_R01_S25  0  6
# phon_R01_S26  0  6
# phon_R01_S27  0  7
# phon_R01_S31  0  6
# phon_R01_S32  0  6
# phon_R01_S33  0  6
# phon_R01_S34  0  6
# phon_R01_S35  0  7
# phon_R01_S37  0  6
# phon_R01_S39  0  6
# phon_R01_S42  6  0
# phon_R01_S43  6  0
# phon_R01_S44  0  6
# phon_R01_S49  6  0
# phon_R01_S50  6  0

# %% [markdown]
# #### Observations on name:
# 1. Each Patients' Status does not have discrepancy across their recordings. i.e. Some recordings show the patient with PD and some show the same patient without PD. Luckily we don't have such a case in given dataset.

# %%
df.pivot_table(index='status', aggfunc=['mean']).T
# For Selected columns
# df.pivot_table(index='status', values=['D2', 'HNR'], aggfunc=['mean']).T
# For multiple aggregations
# df.pivot_table(index='status', values=['D2', 'HNR'], aggfunc=['mean', 'median']).T
# Out:
# status                          0           1
# mean D2                  2.154491    2.456058
#      DFA                 0.695716    0.725408
#      HNR                24.678750   20.974048
#      Jitter:DDP          0.005776    0.011273
#      MDVP:APQ            0.013305    0.027600
#      MDVP:Fhi(Hz)      223.636750  188.441463
#      MDVP:Flo(Hz)      145.207292  106.893558
#      MDVP:Fo(Hz)       181.937771  145.180762
#      MDVP:Jitter(%)      0.003866    0.006989
#      MDVP:Jitter(Abs)    0.000023    0.000051
#      MDVP:PPQ            0.002056    0.003900
#      MDVP:RAP            0.001925    0.003757
#      MDVP:Shimmer        0.017615    0.033658
#      MDVP:Shimmer(dB)    0.162958    0.321204
#      NHR                 0.011483    0.029211
#      PPE                 0.123017    0.233828
#      RPDE                0.442552    0.516816
#      Shimmer:APQ3        0.009504    0.017676
#      Shimmer:APQ5        0.010509    0.020285
#      Shimmer:DDA         0.028511    0.053027
#      spread1            -6.759264   -5.333420
#      spread2             0.160292    0.248133

# %% [markdown]
# #### Some common functions

# %%
def showTree(model, dot_file, png_file, features, class_names, title):

    dot_data = export_graphviz(model, out_file=dot_file, 
                                    feature_names=features,
                                    class_names=class_names,
                                    filled=True, rounded=True,
                                    special_characters=True, 
                                    leaves_parallel=True, 
                                    node_ids=True)

    #These works only when out_file=None
    #graph = graphviz.Source(dot_data)
    #graph

    #To convert .dot to .png
    from subprocess import call
    call(['dot', '-Tpng', dot_file, '-o', png_file, '-Gdpi=600'])

    plt.figure(figsize = (14, 10))
    plt.imshow(plt.imread(png_file))
    plt.axis('off');
    plt.title(title);
    plt.show();

# %%
scoring = ['accuracy', 'precision', 'recall', 'f1']

def model_scores(model_name, y_test, y_pred):
    result = pd.DataFrame(index = ['Accuracy', 'Recall', 'Precision', 'F1 Score'])
    result[model_name] = [accuracy_score(y_test, y_pred), 
                         recall_score(y_test, y_pred),
                         precision_score(y_test, y_pred),
                         f1_score(y_test, y_pred)]
    return result

def model_scores_cross_validation(model_name, d):
    result = pd.DataFrame(index = ['Accuracy', 'Recall', 'Precision', 'F1 Score'])
    result[model_name] = [d['test_accuracy'].mean(), 
                          d['test_recall'].mean(),
                          d['test_precision'].mean(),
                          d['test_f1'].mean()]
    return result

# %%
from collections import Counter

def get_class_weights(y):
    counter = Counter(y)
    majority = max(counter.values())
    return  {cls: round(float(majority)/float(count), 2) for cls, count in counter.items()}

# %% [markdown]
# ### 4. Split the dataset into training and test set in the ratio of 70:30 (Training:Test).
# ### 5. Create the model using “entropy” method of reducing the entropy and fit it to training data. (5 points)
# ### 6. Test the model on test data and what is the accuracy achieved. Capture the predicted values and do a crosstab. (7.5 points)

# %%
random_state = 221271751
X = df.drop(['name', 'just_name', 'status'], axis=1)
y = df['status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=random_state)

title = "DT - Fully Grown"
print("\n", title)
dte_model = DecisionTreeClassifier(criterion='entropy', random_state=random_state)

dte_model.fit(X_train, y_train)
y_pred = dte_model.predict(X_test)

dte_result = model_scores(title, y_test, y_pred)
print(dte_result)
confusion_matrix(y_test, y_pred)
# Out:
#  DT - Fully Grown
#            DT - Fully Grown
# Accuracy           0.796610
# Recall             0.880952
# Precision          0.840909
# F1 Score           0.860465
# array([[10,  7],
#        [ 5, 37]], dtype=int64)

# %% [markdown]
# ### 7. Use regularization parameters of max_depth, min_sample_leaf to recreate the model. What is the impact on the model accuracy? How does regularization help? (20 points)

# %%
# Here I am throwing a few variations while building DecissionTreeClassifier.
# [1] Vary max_depth and min_samples on each iteration both from 1 to 6.
#     In outer loop, I vary max_depth and in the inner loop, I vary min_samples_leaf 
#     which gives me various combinations of max_depth and min_samples_leaf like 
#       max_depth = 1, min_samples_leaf = 1 OR
#       max_depth = 1, min_samples_leaf = 2 OR
#       max_depth = 1, min_samples_leaf = 3 OR
#       ...
#       ...
#       max_depth = 6, min_samples_leaf = 6
# [2] Use class_weights to address Class imbalance problem - In y_train there are 31 cases without PD and 105 with PD
#     which means this dataset has more than 3 times (3.38 times) records of PD than without PD. Thus, we need to pass 
#     class weight to balance the dataset.

random_state = 221271751
X = df.drop(['name', 'just_name', 'status'], axis=1)
y = df['status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=random_state)

class_weights = get_class_weights(y_train)

DT_results = pd.DataFrame()

for depth in np.arange(1,7): 
    for min_leaf in np.arange(1,7):
        title_reg = "DT-({0},{1})".format(depth, min_leaf)
        dte_model_reg = DecisionTreeClassifier(criterion = 'entropy', 
                                               class_weight = class_weights, 
                                               max_depth = depth, 
                                               min_samples_leaf = min_leaf, 
                                               random_state=random_state)
        dte_model_reg.fit(X_train, y_train)
        y_pred_reg = dte_model_reg.predict(X_test)

        res = model_scores(title_reg, y_test, y_pred_reg)
        
        DT_results = pd.concat([DT_results, res], axis=1, sort=False)

# %%
y_train.value_counts()
# Out:
# 1    105
# 0     31
# Name: status, dtype: int64

# %%
DT_results.T
# Out:
#           Accuracy    Recall  Precision  F1 Score
# DT-(1,1)  0.677966  0.619048   0.896552  0.732394
# DT-(1,2)  0.677966  0.619048   0.896552  0.732394
# DT-(1,3)  0.677966  0.619048   0.896552  0.732394
# DT-(1,4)  0.677966  0.619048   0.896552  0.732394
# DT-(1,5)  0.677966  0.619048   0.896552  0.732394
# DT-(1,6)  0.677966  0.619048   0.896552  0.732394
# DT-(2,1)  0.677966  0.619048   0.896552  0.732394
# DT-(2,2)  0.677966  0.619048   0.896552  0.732394
# DT-(2,3)  0.677966  0.619048   0.896552  0.732394
# DT-(2,4)  0.677966  0.619048   0.896552  0.732394
# DT-(2,5)  0.677966  0.619048   0.896552  0.732394
# DT-(2,6)  0.677966  0.619048   0.896552  0.732394
# DT-(3,1)  0.796610  0.857143   0.857143  0.857143
# DT-(3,2)  0.796610  0.857143   0.857143  0.857143
# DT-(3,3)  0.796610  0.857143   0.857143  0.857143
# DT-(3,4)  0.796610  0.857143   0.857143  0.857143
# DT-(3,5)  0.796610  0.857143   0.857143  0.857143
# DT-(3,6)  0.796610  0.857143   0.857143  0.857143
# DT-(4,1)  0.796610  0.833333   0.875000  0.853659
# DT-(4,2)  0.796610  0.833333   0.875000  0.853659
# DT-(4,3)  0.796610  0.833333   0.875000  0.853659
# DT-(4,4)  0.796610  0.833333   0.875000  0.853659
# DT-(4,5)  0.796610  0.833333   0.875000  0.853659
# DT-(4,6)  0.796610  0.833333   0.875000  0.853659
# DT-(5,1)  0.813559  0.857143   0.878049  0.867470
# DT-(5,2)  0.813559  0.857143   0.878049  0.867470
# DT-(5,3)  0.796610  0.833333   0.875000  0.853659
# DT-(5,4)  0.796610  0.833333   0.875000  0.853659
# DT-(5,5)  0.796610  0.833333   0.875000  0.853659
# DT-(5,6)  0.796610  0.833333   0.875000  0.853659
# DT-(6,1)  0.830508  0.880952   0.880952  0.880952
# DT-(6,2)  0.830508  0.880952   0.880952  0.880952
# DT-(6,3)  0.830508  0.880952   0.880952  0.880952
# DT-(6,4)  0.830508  0.880952   0.880952  0.880952
# DT-(6,5)  0.830508  0.880952   0.880952  0.880952
# DT-(6,6)  0.830508  0.880952   0.880952  0.880952

# %%
d1 = DT_results.T.reset_index()
sns.catplot(data = d1, x = 'index', y = 'F1 Score', height=9, aspect=3)

# %% [markdown]
# ##### Observations:
# 1. Decision Tree at max_depth of 6 gives highest F1 Score (88.09 %). But that would be as good as fully grown Decission Tree, hence suffer from Overfit problem (Variance)
# 2. Decision Tree at max_depth of 5 and min_samples_leaf of 1 & 2 gives second best F1 Score (86.74). This may not be as bad as Decission Tree with max_depth 6. So it may not suffer from Overfit problem (Variance).

# %% [markdown]
# ### Extra Work - Visualizing Decision Trees with various combinations of max_depth & min_samples_leaf

# %%
title_4_5 = "DT-(4, 5)"
dte_model_4_5 = DecisionTreeClassifier(criterion = 'entropy', 
                                       class_weight=class_weights, 
                                       max_depth = 4, 
                                       min_samples_leaf = 5, 
                                       random_state = random_state)
dte_model_4_5.fit(X_train, y_train)

title_4_6 = "DT-(4, 6)"
dte_model_4_6 = DecisionTreeClassifier(criterion = 'entropy', 
                                       class_weight=class_weights, 
                                       max_depth = 4, 
                                       min_samples_leaf = 6, 
                                       random_state = random_state)
dte_model_4_6.fit(X_train, y_train)

title_5_1 = "DT-(5, 1)"
dte_model_5_1 = DecisionTreeClassifier(criterion = 'entropy', 
                                       class_weight=class_weights, 
                                       max_depth = 5, 
                                       min_samples_leaf = 1, 
                                       random_state = random_state)
dte_model_5_1.fit(X_train, y_train)

title_5_2 = "DT-(5, 2)"
dte_model_5_2 = DecisionTreeClassifier(criterion = 'entropy', 
                                       class_weight=class_weights, 
                                       max_depth = 5, 
                                       min_samples_leaf = 2, 
                                       random_state = random_state)
dte_model_5_2.fit(X_train, y_train)

title_6_1 = "DT-(6, 1)"
dte_model_6_1 = DecisionTreeClassifier(criterion = 'entropy', 
                                       class_weight=class_weights, 
                                       max_depth = 6, 
                                       min_samples_leaf = 1, 
                                       random_state = random_state)
dte_model_6_1.fit(X_train, y_train)

title_6_2 = "DT-(6, 2)"
dte_model_6_2 = DecisionTreeClassifier(criterion = 'entropy', 
                                       class_weight=class_weights, 
                                       max_depth = 6, 
                                       min_samples_leaf = 2, 
                                       random_state = random_state)
dte_model_6_2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight={1: 1.0, 0: 3.39}, criterion='entropy',
#             max_depth=6, max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=2, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=221271751, splitter='best')

# %%
class_names = ['Non PD', 'PD']

# %%
features=X.columns

dot_file = 'dte_FULL.dot'
png_file = 'dte_FULL.png'
model = dte_model
title = title
showTree(model, dot_file, png_file, features, class_names, title)

# %%
dot_file = 'dte_model_4_5.dot'
png_file = 'dte_model_4_5.png'
model = dte_model_4_5
title = title_4_5
showTree(model, dot_file, png_file, features, class_names, title)

# %%
dot_file = 'dte_model_4_6.dot'
png_file = 'dte_model_4_6.png'
model = dte_model_4_6
title = title_4_6
showTree(model, dot_file, png_file, features, class_names, title)

# %%
dot_file = 'dte_model_5_1.dot'
png_file = 'dte_model_5_1.png'
model = dte_model_5_1
title = title_5_1
showTree(model, dot_file, png_file, features, class_names, title)

# %%
dot_file = 'dte_model_5_2.dot'
png_file = 'dte_model_5_2.png'
model = dte_model_5_2
title = title_5_2
showTree(model, dot_file, png_file, features, class_names, title)

# %%
dot_file = 'dte_model_6_1.dot'
png_file = 'dte_model_6_1.png'
model = dte_model_6_1
title = title_6_1
showTree(model, dot_file, png_file, features, class_names, title)

# %%
dot_file = 'dte_model_6_2.dot'
png_file = 'dte_model_6_2.png'
model = dte_model_6_2
title = title_6_2
showTree(model, dot_file, png_file, features, class_names, title)

# %% [markdown]
# #### 8. Next implement the decision tree using Random Forest. What is the optimal number of trees that gives the best result? (10 points)

# %%
estimator_counts = np.arange(1, 125, 2)
scores = pd.DataFrame(index=estimator_counts)
opt_scores = pd.DataFrame()
opt_f1 = 0
for cnt in estimator_counts:
    model = RandomForestClassifier(criterion = 'entropy',
                                       n_estimators = cnt, 
                                       random_state = random_state)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    f1 = f1_score(y_test, y_pred)
    scores.at[cnt, 'F1 Score'] = f1
    if (f1 > opt_f1):
        opt_scores = model_scores("RF-({0})".format(cnt), y_pred, y_test)
        opt_f1 = f1


result_rf = opt_scores
optimum_estimator = scores['F1 Score'].idxmax()
max_score = scores['F1 Score'].max()

optimum_estimator, max_score
# Out:
# (5, 0.9545454545454545)

# %%
print("\nOptimal number of trees that gives the best result is: {0}, with F1-score {1}".format(optimum_estimator, max_score ))

plt.figure(figsize=(18, 8))
plt.annotate('max', xy=((optimum_estimator/2)-1, max_score))
sns.pointplot(estimator_counts, scores['F1 Score'])
plt.show()
# Out:
# Optimal number of trees that gives the best result is: 5, with F1-score 0.9545454545454545

# %%
final_result = pd.DataFrame()
final_result = pd.concat([result_rf, 
                          DT_results['DT-(4,5)'], 
                          DT_results['DT-(4,6)'], 
                          DT_results['DT-(5,1)'], 
                          DT_results['DT-(5,2)'], 
                          DT_results['DT-(6,1)'], 
                          DT_results['DT-(6,2)']], axis=1, sort=False)
final_result
# Out:
#              RF-(5)  DT-(4,5)  DT-(4,6)  DT-(5,1)  DT-(5,2)  DT-(6,1)  \
# Accuracy   0.932203  0.796610  0.796610  0.813559  0.813559  0.830508
# Recall     0.913043  0.833333  0.833333  0.857143  0.857143  0.880952
# Precision  1.000000  0.875000  0.875000  0.878049  0.878049  0.880952
# F1 Score   0.954545  0.853659  0.853659  0.867470  0.867470  0.880952
#
#            DT-(6,2)
# Accuracy   0.830508
# Recall     0.880952
# Precision  0.880952
# F1 Score   0.880952

# %% [markdown]
# ### Observation:
# 1. With Random Forest, we can achieve highest F1 Score when we use total base estimators = 5
# 2. Overall for given dataset, Random Forest gives way better performance than independent Decision Tree
